# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2    # "cv2" 
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=np.nan)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)
# Out:
# WARNING:tensorflow:From C:\Users\madhusiha\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
cam = cv2.VideoCapture(0)

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from Lakshman is 1.0341766
# Euclidean distance from Madhu is 1.2155051
# Euclidean distance from Sujatha is 1.1115707
# Euclidean distance from Lakshman is 0.87740386
# Euclidean distance from Madhu is 0.7088836
# Euclidean distance from Sujatha is 0.58254904
# Euclidean distance from Lakshman is 0.9539615
# Euclidean distance from Madhu is 0.6223168
# Euclidean distance from Sujatha is 0.567231
# Euclidean distance from Lakshman is 0.9838648
# Euclidean distance from Madhu is 1.2085358
# Euclidean distance from Sujatha is 1.0374656
# Euclidean distance from Lakshman is 0.8901767
# Euclidean distance from Madhu is 0.7569265
# Euclidean distance from Sujatha is 0.70083153
# Euclidean distance from Lakshman is 0.78865767
# Euclidean distance from Madhu is 0.8283221
# Euclidean distance from Sujatha is 0.7183218
# Euclidean distance from Lakshman is 0.9072596
# Euclidean distance from Madhu is 0.82600266
# Euclidean distance from Sujatha is 0.76884055
# Euclidean distance from Lakshman is 0.9125995
# Euclidean distance from Madhu is 0.7313191
# Euclidean distance from Sujatha is 0.6865334
# Euclidean distance from Lakshman is 0.88914907
# Euclidean distance from Madhu is 0.67500854
# Euclidean distance from Sujatha is 0.6004144
# Euclidean distance from Lakshman is 0.88571435
# Euclidean distance from Madhu is 0.754307
# Euclidean distance from Sujatha is 0.6357958
# Euclidean distance from Lakshman is 0.9271821
# Euclidean distance from Madhu is 0.8945669
# Euclidean distance from Sujatha is 0.8082498
# Euclidean distance from Lakshman is 0.983076
# Euclidean distance from Madhu is 1.1232849
# Euclidean distance from Sujatha is 1.0144634
# Euclidean distance from Lakshman is 0.86359817
# Euclidean distance from Madhu is 0.7173829
# Euclidean distance from Sujatha is 0.622414
# Euclidean distance from Lakshman is 0.82216996
# Euclidean distance from Madhu is 0.8041973
# Euclidean distance from Sujatha is 0.69701296
# Euclidean distance from Lakshman is 0.89101607
# Euclidean distance from Madhu is 0.6863168
# Euclidean distance from Sujatha is 0.5954255
# Euclidean distance from Lakshman is 0.8774637
# Euclidean distance from Madhu is 0.78394526
# Euclidean distance from Sujatha is 0.67206
# Euclidean distance from Lakshman is 0.8626353
# Euclidean distance from Madhu is 0.7984733
# Euclidean distance from Sujatha is 0.6892144
# Euclidean distance from Lakshman is 0.8128784
# Euclidean distance from Madhu is 0.71434855
# Euclidean distance from Sujatha is 0.56321657
# Euclidean distance from Lakshman is 1.0450583
# Euclidean distance from Madhu is 1.1744716
# Euclidean distance from Sujatha is 1.074286
# Euclidean distance from Lakshman is 0.86186945
# Euclidean distance from Madhu is 0.7485022
# Euclidean distance from Sujatha is 0.64620405
# Euclidean distance from Lakshman is 0.9309903
# Euclidean distance from Madhu is 0.63732684
# Euclidean distance from Sujatha is 0.5407575
# Euclidean distance from Lakshman is 0.95399183
# Euclidean distance from Madhu is 0.6004833
# Euclidean distance from Sujatha is 0.5566473
# Euclidean distance from Lakshman is 0.9799457
# Euclidean distance from Madhu is 0.69783556
# Euclidean distance from Sujatha is 0.6834644
# Euclidean distance from Lakshman is 0.9700928
# Euclidean distance from Madhu is 0.78371614
# Euclidean distance from Sujatha is 0.76099885
# Euclidean distance from Lakshman is 0.9028145
# Euclidean distance from Madhu is 0.7816454
# Euclidean distance from Sujatha is 0.7240629
# Euclidean distance from Lakshman is 0.9684556
# Euclidean distance from Madhu is 0.7688368
# Euclidean distance from Sujatha is 0.752739
# Euclidean distance from Lakshman is 0.97289264
# Euclidean distance from Madhu is 0.745456
# Euclidean distance from Sujatha is 0.7362337
# Euclidean distance from Lakshman is 0.93007207
# Euclidean distance from Madhu is 0.7643685
# Euclidean distance from Sujatha is 0.72109133
# Euclidean distance from Lakshman is 1.0038735
# Euclidean distance from Madhu is 1.2438446
# Euclidean distance from Sujatha is 1.1362942
# Euclidean distance from Lakshman is 0.9811344
# Euclidean distance from Madhu is 0.7616221
# Euclidean distance from Sujatha is 0.72635317
# Euclidean distance from Lakshman is 0.9669873
# Euclidean distance from Madhu is 0.7586864
# Euclidean distance from Sujatha is 0.7367295
# Euclidean distance from Lakshman is 0.97578824
# Euclidean distance from Madhu is 0.74682206
# Euclidean distance from Sujatha is 0.73107255
# Euclidean distance from Lakshman is 1.0329189
# Euclidean distance from Madhu is 0.73805016
# Euclidean distance from Sujatha is 0.7325312
# Euclidean distance from Lakshman is 1.0987931
# Euclidean distance from Madhu is 0.5942111
# Euclidean distance from Sujatha is 0.6641301
# Euclidean distance from Lakshman is 0.9459179
# Euclidean distance from Madhu is 0.7204559
# Euclidean distance from Sujatha is 0.6586188
# Euclidean distance from Lakshman is 0.9392232
# Euclidean distance from Madhu is 0.74276686
# Euclidean distance from Sujatha is 0.6442212
# Euclidean distance from Lakshman is 0.8485681
# Euclidean distance from Madhu is 0.8597299
# Euclidean distance from Sujatha is 0.7456696
# Euclidean distance from Lakshman is 0.91081274
# Euclidean distance from Madhu is 0.8598899
# Euclidean distance from Sujatha is 0.7280794
# Euclidean distance from Lakshman is 0.885278
# Euclidean distance from Madhu is 0.78529364
# Euclidean distance from Sujatha is 0.677822
# Euclidean distance from Lakshman is 0.94038653
# Euclidean distance from Madhu is 0.76537406
# Euclidean distance from Sujatha is 0.68909574
# Euclidean distance from Lakshman is 0.95784163
# Euclidean distance from Madhu is 0.82144094
# Euclidean distance from Sujatha is 0.736665
# Euclidean distance from Lakshman is 0.9576279
# Euclidean distance from Madhu is 0.74125904
# Euclidean distance from Sujatha is 0.6558285
# Euclidean distance from Lakshman is 1.0076082
# Euclidean distance from Madhu is 0.66968983
# Euclidean distance from Sujatha is 0.60787135
# Euclidean distance from Lakshman is 0.9563666
# Euclidean distance from Madhu is 0.6831988
# Euclidean distance from Sujatha is 0.61543643
# Euclidean distance from Lakshman is 1.0289835
# Euclidean distance from Madhu is 1.1983482
# Euclidean distance from Sujatha is 1.0724465
# Euclidean distance from Lakshman is 0.91942555
# Euclidean distance from Madhu is 0.7403483
# Euclidean distance from Sujatha is 0.64513624
# Euclidean distance from Lakshman is 0.94429225
# Euclidean distance from Madhu is 0.71643573
# Euclidean distance from Sujatha is 0.65229523
# Euclidean distance from Lakshman is 1.0230174
# Euclidean distance from Madhu is 0.68940914
# Euclidean distance from Sujatha is 0.6543207
# Euclidean distance from Lakshman is 0.94752926
# Euclidean distance from Madhu is 0.75000334
# Euclidean distance from Sujatha is 0.67677754
# Euclidean distance from Lakshman is 1.0054963
# Euclidean distance from Madhu is 1.1798943
# Euclidean distance from Sujatha is 1.0788139
# Euclidean distance from Lakshman is 0.9728064
# Euclidean distance from Madhu is 0.7539762
# Euclidean distance from Sujatha is 0.69244915
# Euclidean distance from Lakshman is 0.97615874
# Euclidean distance from Madhu is 0.79973215
# Euclidean distance from Sujatha is 0.7428627
# Euclidean distance from Lakshman is 0.9396157
# Euclidean distance from Madhu is 0.7353453
# Euclidean distance from Sujatha is 0.6888
# Euclidean distance from Lakshman is 0.96446234
# Euclidean distance from Madhu is 0.72666496
# Euclidean distance from Sujatha is 0.6613402
# Euclidean distance from Lakshman is 1.1189692
# Euclidean distance from Madhu is 0.8756701
# Euclidean distance from Sujatha is 0.8849317
# Euclidean distance from Lakshman is 0.9641409
# Euclidean distance from Madhu is 0.75454724
# Euclidean distance from Sujatha is 0.684726
# Euclidean distance from Lakshman is 0.94480014
# Euclidean distance from Madhu is 0.6801013
# Euclidean distance from Sujatha is 0.64101446
# Euclidean distance from Lakshman is 0.9924711
# Euclidean distance from Madhu is 0.8123898
# Euclidean distance from Sujatha is 0.7870475
# Euclidean distance from Lakshman is 0.98001987
# Euclidean distance from Madhu is 0.71459174
# Euclidean distance from Sujatha is 0.69797826
# Euclidean distance from Lakshman is 0.97574586
# Euclidean distance from Madhu is 1.1157881
# Euclidean distance from Sujatha is 1.0115806
# Euclidean distance from Lakshman is 1.0212817
# Euclidean distance from Madhu is 1.1061424
# Euclidean distance from Sujatha is 1.0208794
# Euclidean distance from Lakshman is 0.9825742
# Euclidean distance from Madhu is 0.512126
# Euclidean distance from Sujatha is 0.52482194
# Euclidean distance from Lakshman is 1.0982461
# Euclidean distance from Madhu is 0.5607908
# Euclidean distance from Sujatha is 0.55071545
# Euclidean distance from Lakshman is 0.9990766
# Euclidean distance from Madhu is 0.8054666
# Euclidean distance from Sujatha is 0.65134275
# Euclidean distance from Lakshman is 1.0482013
# Euclidean distance from Madhu is 0.82310325
# Euclidean distance from Sujatha is 0.655687
# Euclidean distance from Lakshman is 0.92934006
# Euclidean distance from Madhu is 0.8846349
# Euclidean distance from Sujatha is 0.68615633
# Euclidean distance from Lakshman is 0.9948395
# Euclidean distance from Madhu is 1.1162771
# Euclidean distance from Sujatha is 0.96112716
# Euclidean distance from Lakshman is 0.9998728
# Euclidean distance from Madhu is 1.0406675
# Euclidean distance from Sujatha is 0.8918573
# Euclidean distance from Lakshman is 1.0196376
# Euclidean distance from Madhu is 1.0495929
# Euclidean distance from Sujatha is 0.89598346
# Euclidean distance from Lakshman is 1.0207224
# Euclidean distance from Madhu is 0.8580393
# Euclidean distance from Sujatha is 0.6701735
# Euclidean distance from Lakshman is 1.0793657
# Euclidean distance from Madhu is 0.8648652
# Euclidean distance from Sujatha is 0.77335113
# Euclidean distance from Lakshman is 1.0812511
# Euclidean distance from Madhu is 1.026949
# Euclidean distance from Sujatha is 0.947066
# Euclidean distance from Lakshman is 0.98712236
# Euclidean distance from Madhu is 1.0580646
# Euclidean distance from Sujatha is 0.9311414
# Euclidean distance from Lakshman is 0.9712607
# Euclidean distance from Madhu is 1.0586483
# Euclidean distance from Sujatha is 0.93204635
# Euclidean distance from Lakshman is 0.9956598
# Euclidean distance from Madhu is 1.0566261
# Euclidean distance from Sujatha is 0.9338882
# Euclidean distance from Lakshman is 0.93079436
# Euclidean distance from Madhu is 1.0008268
# Euclidean distance from Sujatha is 0.8319409
# Euclidean distance from Lakshman is 0.9534012
# Euclidean distance from Madhu is 1.0065753
# Euclidean distance from Sujatha is 0.850644
# Euclidean distance from Lakshman is 1.0034709
# Euclidean distance from Madhu is 1.1762975
# Euclidean distance from Sujatha is 1.0615784
# Euclidean distance from Lakshman is 1.0055624
# Euclidean distance from Madhu is 1.1045043
# Euclidean distance from Sujatha is 0.95353615
# Euclidean distance from Lakshman is 1.0458533
# Euclidean distance from Madhu is 1.146084
# Euclidean distance from Sujatha is 1.0391315
# Euclidean distance from Lakshman is 0.976635
# Euclidean distance from Madhu is 1.0892098
# Euclidean distance from Sujatha is 0.9361144
# Euclidean distance from Lakshman is 1.0472199
# Euclidean distance from Madhu is 1.0600165
# Euclidean distance from Sujatha is 0.95147514
# Euclidean distance from Lakshman is 1.0701386
# Euclidean distance from Madhu is 0.9056855
# Euclidean distance from Sujatha is 0.8235425
# Euclidean distance from Lakshman is 1.0268714
# Euclidean distance from Madhu is 0.9516728
# Euclidean distance from Sujatha is 0.8413681
# Euclidean distance from Lakshman is 1.009066
# Euclidean distance from Madhu is 0.92015564
# Euclidean distance from Sujatha is 0.80406773
# Euclidean distance from Lakshman is 0.96897954
# Euclidean distance from Madhu is 0.7044431
# Euclidean distance from Sujatha is 0.6054867
# Euclidean distance from Lakshman is 0.9909792
# Euclidean distance from Madhu is 1.1868241
# Euclidean distance from Sujatha is 1.0678114
# Euclidean distance from Lakshman is 1.1597445
# Euclidean distance from Madhu is 0.61816365
# Euclidean distance from Sujatha is 0.64837694
# Euclidean distance from Lakshman is 1.134809
# Euclidean distance from Madhu is 0.68361366
# Euclidean distance from Sujatha is 0.6582987
# Euclidean distance from Lakshman is 1.0499825
# Euclidean distance from Madhu is 1.001057
# Euclidean distance from Sujatha is 0.9528159
# Euclidean distance from Lakshman is 1.1105281
# Euclidean distance from Madhu is 0.67659926
# Euclidean distance from Sujatha is 0.6656221
# Euclidean distance from Lakshman is 1.0600494
# Euclidean distance from Madhu is 1.1604809
# Euclidean distance from Sujatha is 1.1598258
# Euclidean distance from Lakshman is 1.1179589
# Euclidean distance from Madhu is 0.65782845
# Euclidean distance from Sujatha is 0.67340964
# Euclidean distance from Lakshman is 1.0483135
# Euclidean distance from Madhu is 0.6871091
# Euclidean distance from Sujatha is 0.654592
# Euclidean distance from Lakshman is 1.03306
# Euclidean distance from Madhu is 1.1256847
# Euclidean distance from Sujatha is 1.1188986
# Euclidean distance from Lakshman is 1.0374357
# Euclidean distance from Madhu is 0.76515573
# Euclidean distance from Sujatha is 0.69190717
# Euclidean distance from Lakshman is 1.0061507
# Euclidean distance from Madhu is 1.1833504
# Euclidean distance from Sujatha is 1.1342558
# Euclidean distance from Lakshman is 1.0892053
# Euclidean distance from Madhu is 0.70847666
# Euclidean distance from Sujatha is 0.69466114
# Euclidean distance from Lakshman is 0.9812956
# Euclidean distance from Madhu is 1.2123351
# Euclidean distance from Sujatha is 1.1482297
# Euclidean distance from Lakshman is 1.0582525
# Euclidean distance from Madhu is 0.72191155
# Euclidean distance from Sujatha is 0.6844943
# Euclidean distance from Lakshman is 0.94810486
# Euclidean distance from Madhu is 1.1277705
# Euclidean distance from Sujatha is 1.0251409
# Euclidean distance from Lakshman is 1.0458267
# Euclidean distance from Madhu is 0.6984078
# Euclidean distance from Sujatha is 0.6561587
# Euclidean distance from Lakshman is 0.9737827
# Euclidean distance from Madhu is 1.1224058
# Euclidean distance from Sujatha is 1.0623671
# Euclidean distance from Lakshman is 1.1948221
# Euclidean distance from Madhu is 0.60251975
# Euclidean distance from Sujatha is 0.6806863
# Euclidean distance from Lakshman is 1.006738
# Euclidean distance from Madhu is 1.1160096
# Euclidean distance from Sujatha is 1.0553491
# Euclidean distance from Lakshman is 1.1281446
# Euclidean distance from Madhu is 0.6389319
# Euclidean distance from Sujatha is 0.6462886
# Euclidean distance from Lakshman is 1.0267634
# Euclidean distance from Madhu is 1.127775
# Euclidean distance from Sujatha is 1.113358
# Euclidean distance from Lakshman is 1.0982313
# Euclidean distance from Madhu is 0.7014255
# Euclidean distance from Sujatha is 0.67018485
# Euclidean distance from Lakshman is 1.0629035
# Euclidean distance from Madhu is 1.089098
# Euclidean distance from Sujatha is 1.0731441
# Euclidean distance from Lakshman is 1.0068724
# Euclidean distance from Madhu is 0.818158
# Euclidean distance from Sujatha is 0.70723194
# Euclidean distance from Lakshman is 1.0390959
# Euclidean distance from Madhu is 0.9017981
# Euclidean distance from Sujatha is 0.8403483
# Euclidean distance from Lakshman is 1.0497613
# Euclidean distance from Madhu is 1.2098585
# Euclidean distance from Sujatha is 0.9898128
# Euclidean distance from Lakshman is 1.2393671
# Euclidean distance from Madhu is 1.2934985
# Euclidean distance from Sujatha is 1.2450337
# Euclidean distance from Lakshman is 1.0117189
# Euclidean distance from Madhu is 1.0891495
# Euclidean distance from Sujatha is 0.9315099
# Euclidean distance from Lakshman is 1.072752
# Euclidean distance from Madhu is 1.0967437
# Euclidean distance from Sujatha is 1.0286932
# Euclidean distance from Lakshman is 1.1096311
# Euclidean distance from Madhu is 1.1311582
# Euclidean distance from Sujatha is 1.1231755
# Euclidean distance from Lakshman is 1.0870032
# Euclidean distance from Madhu is 1.0824469
# Euclidean distance from Sujatha is 1.0157607
# Euclidean distance from Lakshman is 1.0218394
# Euclidean distance from Madhu is 0.9475145
# Euclidean distance from Sujatha is 0.9001062
# Euclidean distance from Lakshman is 0.9688057
# Euclidean distance from Madhu is 1.059019
# Euclidean distance from Sujatha is 0.99554133
# Euclidean distance from Lakshman is 1.1182162
# Euclidean distance from Madhu is 0.9583221
# Euclidean distance from Sujatha is 0.96321976
# Euclidean distance from Lakshman is 1.1104347
# Euclidean distance from Madhu is 0.99579364
# Euclidean distance from Sujatha is 0.99416715
# Euclidean distance from Lakshman is 1.1386628
# Euclidean distance from Madhu is 1.1662225
# Euclidean distance from Sujatha is 1.1728747
# Euclidean distance from Lakshman is 1.1231251
# Euclidean distance from Madhu is 1.0323484
# Euclidean distance from Sujatha is 1.0138043
# Euclidean distance from Lakshman is 1.0716501
# Euclidean distance from Madhu is 1.1333185
# Euclidean distance from Sujatha is 1.1195027
# Euclidean distance from Lakshman is 1.0881484
# Euclidean distance from Madhu is 0.96231467
# Euclidean distance from Sujatha is 0.93252057
# Euclidean distance from Lakshman is 1.061137
# Euclidean distance from Madhu is 1.0278429
# Euclidean distance from Sujatha is 0.9893529
# Euclidean distance from Lakshman is 1.0688854
# Euclidean distance from Madhu is 1.0585833
# Euclidean distance from Sujatha is 1.0353577
# Euclidean distance from Lakshman is 1.0573407
# Euclidean distance from Madhu is 1.0593072
# Euclidean distance from Sujatha is 0.9792404
# Euclidean distance from Lakshman is 1.01878
# Euclidean distance from Madhu is 1.1416535
# Euclidean distance from Sujatha is 1.0835114
# Euclidean distance from Lakshman is 1.0719458
# Euclidean distance from Madhu is 0.8953244
# Euclidean distance from Sujatha is 0.8498851
# Euclidean distance from Lakshman is 1.0475214
# Euclidean distance from Madhu is 1.0078158
# Euclidean distance from Sujatha is 0.98132056
# Euclidean distance from Lakshman is 1.0087388
# Euclidean distance from Madhu is 0.8934354
# Euclidean distance from Sujatha is 0.8356261
# Euclidean distance from Lakshman is 1.1280856
# Euclidean distance from Madhu is 0.98654497
# Euclidean distance from Sujatha is 0.9559172
# Euclidean distance from Lakshman is 0.954058
# Euclidean distance from Madhu is 0.7810183
# Euclidean distance from Sujatha is 0.6926566
# Euclidean distance from Lakshman is 1.0570949
# Euclidean distance from Madhu is 0.7583563
# Euclidean distance from Sujatha is 0.8342193
# Euclidean distance from Lakshman is 1.0335442
# Euclidean distance from Madhu is 0.6634769
# Euclidean distance from Sujatha is 0.6159943
# Euclidean distance from Lakshman is 1.2337065
# Euclidean distance from Madhu is 0.7453865
# Euclidean distance from Sujatha is 0.80991
# Euclidean distance from Lakshman is 1.1229813
# Euclidean distance from Madhu is 0.79390144
# Euclidean distance from Sujatha is 0.8680625
# Euclidean distance from Lakshman is 1.1580718
# Euclidean distance from Madhu is 1.0055512
# Euclidean distance from Sujatha is 1.0598191
# Euclidean distance from Lakshman is 1.1808645
# Euclidean distance from Madhu is 0.9059906
# Euclidean distance from Sujatha is 0.9994101
# Euclidean distance from Lakshman is 1.1501473
# Euclidean distance from Madhu is 0.8883031
# Euclidean distance from Sujatha is 0.92861
# Euclidean distance from Lakshman is 1.1573582
# Euclidean distance from Madhu is 0.9127838
# Euclidean distance from Sujatha is 1.006506
# Euclidean distance from Lakshman is 1.1862767
# Euclidean distance from Madhu is 0.9572836
# Euclidean distance from Sujatha is 1.0045484
# Euclidean distance from Lakshman is 1.1817741
# Euclidean distance from Madhu is 1.0066373
# Euclidean distance from Sujatha is 1.0639123
# Euclidean distance from Lakshman is 1.071903
# Euclidean distance from Madhu is 0.8782
# Euclidean distance from Sujatha is 0.93786925
# Euclidean distance from Lakshman is 0.96489817
# Euclidean distance from Madhu is 0.76165605
# Euclidean distance from Sujatha is 0.81718314
# Euclidean distance from Lakshman is 1.0969197
# Euclidean distance from Madhu is 0.63299316
# Euclidean distance from Sujatha is 0.71864253
# Euclidean distance from Lakshman is 0.9915166
# Euclidean distance from Madhu is 0.56528217
# Euclidean distance from Sujatha is 0.6191419
# Euclidean distance from Lakshman is 1.118586
# Euclidean distance from Madhu is 0.6130478
# Euclidean distance from Sujatha is 0.6677909
# Euclidean distance from Lakshman is 1.029762
# Euclidean distance from Madhu is 0.5921386
# Euclidean distance from Sujatha is 0.63836837
# Euclidean distance from Lakshman is 1.0969424
# Euclidean distance from Madhu is 0.63490367
# Euclidean distance from Sujatha is 0.69095916
# Euclidean distance from Lakshman is 1.1236738
# Euclidean distance from Madhu is 0.6175102
# Euclidean distance from Sujatha is 0.6781759
# Euclidean distance from Lakshman is 1.1007736
# Euclidean distance from Madhu is 0.5852998
# Euclidean distance from Sujatha is 0.6461882
# Euclidean distance from Lakshman is 1.101099
# Euclidean distance from Madhu is 0.6491594
# Euclidean distance from Sujatha is 0.6945869
# Euclidean distance from Lakshman is 1.1126515
# Euclidean distance from Madhu is 0.6685896
# Euclidean distance from Sujatha is 0.70117724
# Euclidean distance from Lakshman is 1.1423968
# Euclidean distance from Madhu is 0.6435373
# Euclidean distance from Sujatha is 0.72058487
# Euclidean distance from Lakshman is 1.1120778
# Euclidean distance from Madhu is 0.6306743
# Euclidean distance from Sujatha is 0.70924866
# Euclidean distance from Lakshman is 1.0871434
# Euclidean distance from Madhu is 0.66026706
# Euclidean distance from Sujatha is 0.72662926
# Euclidean distance from Lakshman is 1.1834656
# Euclidean distance from Madhu is 0.7283224
# Euclidean distance from Sujatha is 0.8105419
# Euclidean distance from Lakshman is 1.1158398
# Euclidean distance from Madhu is 0.62232685
# Euclidean distance from Sujatha is 0.7107301
# Euclidean distance from Lakshman is 1.0820891
# Euclidean distance from Madhu is 0.6304122
# Euclidean distance from Sujatha is 0.70257235
# Euclidean distance from Lakshman is 1.1324676
# Euclidean distance from Madhu is 0.6699623
# Euclidean distance from Sujatha is 0.753172
# Euclidean distance from Lakshman is 1.1313671
# Euclidean distance from Madhu is 0.9102683
# Euclidean distance from Sujatha is 0.9274554
# Euclidean distance from Lakshman is 1.0471385
# Euclidean distance from Madhu is 0.95220566
# Euclidean distance from Sujatha is 0.8936035
# Euclidean distance from Lakshman is 1.1175485
# Euclidean distance from Madhu is 1.100295
# Euclidean distance from Sujatha is 1.0770001
# Euclidean distance from Lakshman is 1.1942303
# Euclidean distance from Madhu is 1.0711464
# Euclidean distance from Sujatha is 1.0997325
# Euclidean distance from Lakshman is 1.0177404
# Euclidean distance from Madhu is 1.0751358
# Euclidean distance from Sujatha is 0.99941444
# Euclidean distance from Lakshman is 1.112065
# Euclidean distance from Madhu is 0.9232687
# Euclidean distance from Sujatha is 0.91353613
# Euclidean distance from Lakshman is 1.1131756
# Euclidean distance from Madhu is 0.9621796
# Euclidean distance from Sujatha is 0.9448916
# Euclidean distance from Lakshman is 0.9851075
# Euclidean distance from Madhu is 1.1267781
# Euclidean distance from Sujatha is 1.0706732
# Euclidean distance from Lakshman is 1.0758997
# Euclidean distance from Madhu is 0.96958333
# Euclidean distance from Sujatha is 0.9407014
# Euclidean distance from Lakshman is 1.0644464
# Euclidean distance from Madhu is 0.96814126
# Euclidean distance from Sujatha is 0.93072796
# Euclidean distance from Lakshman is 0.98041433
# Euclidean distance from Madhu is 1.1059041
# Euclidean distance from Sujatha is 1.0560595
# Euclidean distance from Lakshman is 1.008773
# Euclidean distance from Madhu is 1.0396951
# Euclidean distance from Sujatha is 0.9925312
# Euclidean distance from Lakshman is 0.96259654
# Euclidean distance from Madhu is 1.0541697
# Euclidean distance from Sujatha is 0.9993841
# Euclidean distance from Lakshman is 1.135747
# Euclidean distance from Madhu is 0.99070394
# Euclidean distance from Sujatha is 0.9992896
# Euclidean distance from Lakshman is 1.072865
# Euclidean distance from Madhu is 0.9478757
# Euclidean distance from Sujatha is 0.9530635
# Euclidean distance from Lakshman is 1.0907272
# Euclidean distance from Madhu is 0.924957
# Euclidean distance from Sujatha is 0.9268969
# Euclidean distance from Lakshman is 1.06792
# Euclidean distance from Madhu is 0.7415189
# Euclidean distance from Sujatha is 0.7771514
# Euclidean distance from Lakshman is 1.0150074
# Euclidean distance from Madhu is 0.72195935
# Euclidean distance from Sujatha is 0.7279767
# Euclidean distance from Lakshman is 1.0969639
# Euclidean distance from Madhu is 0.956841
# Euclidean distance from Sujatha is 0.9836181
# Euclidean distance from Lakshman is 1.0951698
# Euclidean distance from Madhu is 0.895411
# Euclidean distance from Sujatha is 0.8939877
# Euclidean distance from Lakshman is 1.1179441
# Euclidean distance from Madhu is 0.9577472
# Euclidean distance from Sujatha is 0.972368
# Euclidean distance from Lakshman is 1.0501366
# Euclidean distance from Madhu is 0.92406887
# Euclidean distance from Sujatha is 0.90744376
# Euclidean distance from Lakshman is 0.9515058
# Euclidean distance from Madhu is 1.0551007
# Euclidean distance from Sujatha is 1.0200217
# Euclidean distance from Lakshman is 0.9487595
# Euclidean distance from Madhu is 0.9088353
# Euclidean distance from Sujatha is 0.8848758
# Euclidean distance from Lakshman is 0.9717531
# Euclidean distance from Madhu is 0.97037655
# Euclidean distance from Sujatha is 0.92902637
# Euclidean distance from Lakshman is 0.8907679
# Euclidean distance from Madhu is 0.9550368
# Euclidean distance from Sujatha is 0.8581416
# Euclidean distance from Lakshman is 1.0787566
# Euclidean distance from Madhu is 0.93474597
# Euclidean distance from Sujatha is 0.9379285
# Euclidean distance from Lakshman is 1.0278947
# Euclidean distance from Madhu is 1.013967
# Euclidean distance from Sujatha is 0.96860343
# Euclidean distance from Lakshman is 0.9464026
# Euclidean distance from Madhu is 0.9653074
# Euclidean distance from Sujatha is 0.8858044
# Euclidean distance from Lakshman is 1.0981637
# Euclidean distance from Madhu is 0.9758121
# Euclidean distance from Sujatha is 0.97575545
# Euclidean distance from Lakshman is 0.97038317
# Euclidean distance from Madhu is 0.9680333
# Euclidean distance from Sujatha is 0.9228107
# Euclidean distance from Lakshman is 1.0331434
# Euclidean distance from Madhu is 0.9070588
# Euclidean distance from Sujatha is 0.89296645
# Euclidean distance from Lakshman is 1.0735096
# Euclidean distance from Madhu is 0.8198414
# Euclidean distance from Sujatha is 0.8947734
# Euclidean distance from Lakshman is 1.2883812
# Euclidean distance from Madhu is 0.9797743
# Euclidean distance from Sujatha is 1.1038024
# Euclidean distance from Lakshman is 1.3249063
# Euclidean distance from Madhu is 1.2279348
# Euclidean distance from Sujatha is 1.3216299
# Euclidean distance from Lakshman is 1.1599791
# Euclidean distance from Madhu is 1.1600717
# Euclidean distance from Sujatha is 1.1853396
# Euclidean distance from Lakshman is 1.0485901
# Euclidean distance from Madhu is 1.1296736
# Euclidean distance from Sujatha is 1.0626884
# Euclidean distance from Lakshman is 1.205097
# Euclidean distance from Madhu is 1.1510336
# Euclidean distance from Sujatha is 1.2032136
# Euclidean distance from Lakshman is 1.1517457
# Euclidean distance from Madhu is 1.1527808
# Euclidean distance from Sujatha is 1.1873398
# Euclidean distance from Lakshman is 1.129889
# Euclidean distance from Madhu is 0.94323045
# Euclidean distance from Sujatha is 0.9203103
# Euclidean distance from Lakshman is 1.0504913
# Euclidean distance from Madhu is 1.0738058
# Euclidean distance from Sujatha is 1.0349556
# Euclidean distance from Lakshman is 1.0102386
# Euclidean distance from Madhu is 1.1018263
# Euclidean distance from Sujatha is 1.0176274
# Euclidean distance from Lakshman is 1.2171928
# Euclidean distance from Madhu is 1.1548051
# Euclidean distance from Sujatha is 1.2019354
# Euclidean distance from Lakshman is 1.0572448
# Euclidean distance from Madhu is 1.0167882
# Euclidean distance from Sujatha is 0.9782849
# Euclidean distance from Lakshman is 1.1930379
# Euclidean distance from Madhu is 1.1814021
# Euclidean distance from Sujatha is 1.212306
# Euclidean distance from Lakshman is 1.3231555
# Euclidean distance from Madhu is 1.1657517
# Euclidean distance from Sujatha is 1.2430238
# Euclidean distance from Lakshman is 1.158061
# Euclidean distance from Madhu is 1.1070807
# Euclidean distance from Sujatha is 1.0281048
# Euclidean distance from Lakshman is 1.3975064
# Euclidean distance from Madhu is 1.2163017
# Euclidean distance from Sujatha is 1.3247683
# Euclidean distance from Lakshman is 1.158333
# Euclidean distance from Madhu is 0.9565148
# Euclidean distance from Sujatha is 1.006458
# Euclidean distance from Lakshman is 1.2264869
# Euclidean distance from Madhu is 1.2038614
# Euclidean distance from Sujatha is 1.2434468
# Euclidean distance from Lakshman is 1.0752045
# Euclidean distance from Madhu is 1.2009836
# Euclidean distance from Sujatha is 1.1025561
# Euclidean distance from Lakshman is 1.1734649
# Euclidean distance from Madhu is 1.0747261
# Euclidean distance from Sujatha is 1.1066512
# Euclidean distance from Lakshman is 1.1816087
# Euclidean distance from Madhu is 0.90130323
# Euclidean distance from Sujatha is 0.96873415
# Euclidean distance from Lakshman is 1.1357208
# Euclidean distance from Madhu is 0.84204876
# Euclidean distance from Sujatha is 0.8633889
# Euclidean distance from Lakshman is 1.0297596
# Euclidean distance from Madhu is 0.84889245
# Euclidean distance from Sujatha is 0.8148102
# Euclidean distance from Lakshman is 0.9722764
# Euclidean distance from Madhu is 0.8903922
# Euclidean distance from Sujatha is 0.789322
# Euclidean distance from Lakshman is 0.99257624
# Euclidean distance from Madhu is 0.71254486
# Euclidean distance from Sujatha is 0.621285
# Euclidean distance from Lakshman is 0.943104
# Euclidean distance from Madhu is 0.6895149
# Euclidean distance from Sujatha is 0.5308184
# Euclidean distance from Lakshman is 1.1206822
# Euclidean distance from Madhu is 0.75777924
# Euclidean distance from Sujatha is 0.73011696
# Euclidean distance from Lakshman is 1.046289
# Euclidean distance from Madhu is 0.636089
# Euclidean distance from Sujatha is 0.62188333
# Euclidean distance from Lakshman is 0.99369925
# Euclidean distance from Madhu is 0.8269449
# Euclidean distance from Sujatha is 0.6987134
# Euclidean distance from Lakshman is 1.1266227
# Euclidean distance from Madhu is 0.9503712
# Euclidean distance from Sujatha is 0.8550421
# Euclidean distance from Lakshman is 1.1070838
# Euclidean distance from Madhu is 0.6769238
# Euclidean distance from Sujatha is 0.6957478
# Euclidean distance from Lakshman is 1.0958334
# Euclidean distance from Madhu is 0.5402447
# Euclidean distance from Sujatha is 0.5611807
# Euclidean distance from Lakshman is 1.0371642
# Euclidean distance from Madhu is 0.504183
# Euclidean distance from Sujatha is 0.47267032
# Euclidean distance from Lakshman is 1.0362438
# Euclidean distance from Madhu is 0.662698
# Euclidean distance from Sujatha is 0.59727484
# Euclidean distance from Lakshman is 1.0190865
# Euclidean distance from Madhu is 0.75687647
# Euclidean distance from Sujatha is 0.66616017
# Euclidean distance from Lakshman is 1.1374323
# Euclidean distance from Madhu is 0.7060356
# Euclidean distance from Sujatha is 0.66689146
# Euclidean distance from Lakshman is 1.0987376
# Euclidean distance from Madhu is 0.6173563
# Euclidean distance from Sujatha is 0.5636163
# Euclidean distance from Lakshman is 1.0239377
# Euclidean distance from Madhu is 0.5708664
# Euclidean distance from Sujatha is 0.48872843
# Euclidean distance from Lakshman is 1.0581249
# Euclidean distance from Madhu is 0.7864535
# Euclidean distance from Sujatha is 0.70194334
# Euclidean distance from Lakshman is 1.145037
# Euclidean distance from Madhu is 0.5347436
# Euclidean distance from Sujatha is 0.54751134
# Euclidean distance from Lakshman is 1.0454606
# Euclidean distance from Madhu is 0.7713871
# Euclidean distance from Sujatha is 0.7140624
# Euclidean distance from Lakshman is 1.0525353
# Euclidean distance from Madhu is 0.5844282
# Euclidean distance from Sujatha is 0.5348178
# Euclidean distance from Lakshman is 1.0673195
# Euclidean distance from Madhu is 0.5643675
# Euclidean distance from Sujatha is 0.5361195
# Euclidean distance from Lakshman is 1.0820831
# Euclidean distance from Madhu is 0.7002006
# Euclidean distance from Sujatha is 0.6520352
# Euclidean distance from Lakshman is 1.1016024
# Euclidean distance from Madhu is 0.7179177
# Euclidean distance from Sujatha is 0.6757155
# Euclidean distance from Lakshman is 1.0528237
# Euclidean distance from Madhu is 0.6384766
# Euclidean distance from Sujatha is 0.56153
# Euclidean distance from Lakshman is 1.1190455
# Euclidean distance from Madhu is 0.62253916
# Euclidean distance from Sujatha is 0.58135724
# Euclidean distance from Lakshman is 0.9808175
# Euclidean distance from Madhu is 0.647402
# Euclidean distance from Sujatha is 0.5264001
# Euclidean distance from Lakshman is 1.0172118
# Euclidean distance from Madhu is 0.77067184
# Euclidean distance from Sujatha is 0.65680754
# Euclidean distance from Lakshman is 1.0415361
# Euclidean distance from Madhu is 0.6778303
# Euclidean distance from Sujatha is 0.6071303
# Euclidean distance from Lakshman is 1.1590135
# Euclidean distance from Madhu is 0.6479922
# Euclidean distance from Sujatha is 0.61995715
# Euclidean distance from Lakshman is 1.2010505
# Euclidean distance from Madhu is 0.62371314
# Euclidean distance from Sujatha is 0.64750004
# Euclidean distance from Lakshman is 1.2104537
# Euclidean distance from Madhu is 0.5744924
# Euclidean distance from Sujatha is 0.64090586
# Euclidean distance from Lakshman is 1.2519869
# Euclidean distance from Madhu is 0.60247755
# Euclidean distance from Sujatha is 0.68899924
# Euclidean distance from Lakshman is 1.2021543
# Euclidean distance from Madhu is 0.5873963
# Euclidean distance from Sujatha is 0.6345296
# Euclidean distance from Lakshman is 1.2707487
# Euclidean distance from Madhu is 0.56627464
# Euclidean distance from Sujatha is 0.70404804
# Euclidean distance from Lakshman is 1.1974384
# Euclidean distance from Madhu is 0.6227754
# Euclidean distance from Sujatha is 0.68322015
# Euclidean distance from Lakshman is 1.1743183
# Euclidean distance from Madhu is 0.588553
# Euclidean distance from Sujatha is 0.61812663
# Euclidean distance from Lakshman is 1.1111115
# Euclidean distance from Madhu is 0.6167443
# Euclidean distance from Sujatha is 0.58009315
# Euclidean distance from Lakshman is 1.130651
# Euclidean distance from Madhu is 0.60263395
# Euclidean distance from Sujatha is 0.61621493
# Euclidean distance from Lakshman is 1.1640385
# Euclidean distance from Madhu is 0.5959044
# Euclidean distance from Sujatha is 0.59540415
# Euclidean distance from Lakshman is 1.179496
# Euclidean distance from Madhu is 0.6089731
# Euclidean distance from Sujatha is 0.6240174
# Euclidean distance from Lakshman is 1.1592358
# Euclidean distance from Madhu is 0.6326849
# Euclidean distance from Sujatha is 0.6308978
# Euclidean distance from Lakshman is 1.1502994
# Euclidean distance from Madhu is 0.6633152
# Euclidean distance from Sujatha is 0.6462404
# Euclidean distance from Lakshman is 1.1062996
# Euclidean distance from Madhu is 0.68694234
# Euclidean distance from Sujatha is 0.6430391
# Euclidean distance from Lakshman is 1.040636
# Euclidean distance from Madhu is 0.8674101
# Euclidean distance from Sujatha is 0.7402186
# Euclidean distance from Lakshman is 1.132659
# Euclidean distance from Madhu is 0.6926542
# Euclidean distance from Sujatha is 0.6391436
# Euclidean distance from Lakshman is 1.1570886
# Euclidean distance from Madhu is 0.8956922
# Euclidean distance from Sujatha is 0.8454063
# Euclidean distance from Lakshman is 1.1331092
# Euclidean distance from Madhu is 0.5694447
# Euclidean distance from Sujatha is 0.57470024
# Euclidean distance from Lakshman is 1.0067048
# Euclidean distance from Madhu is 0.677883
# Euclidean distance from Sujatha is 0.50602335
# Euclidean distance from Lakshman is 1.1415803
# Euclidean distance from Madhu is 0.58597434
# Euclidean distance from Sujatha is 0.56430864
